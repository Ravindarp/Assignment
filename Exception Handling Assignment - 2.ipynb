# %%
Q1

# %% [markdown]
# We have to use the Exception class while creating a custom exception because it is the base class for all exceptions in Python. This means that any class that inherits from the Exception class is a valid exception.

# %%
Q2

# %%
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 2)

print_exception_hierarchy(BaseException)
# Out:
# BaseException
#   Exception
#     TypeError
#       FloatOperation
#       MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#       ModuleNotFoundError
#       ZipImportError
#     OSError
#       ConnectionError
#         BrokenPipeError
#         ConnectionAbortedError
#         ConnectionRefusedError
#         ConnectionResetError
#           RemoteDisconnected
#       BlockingIOError
#       ChildProcessError
#       FileExistsError
#       FileNotFoundError
#       IsADirectoryError
#       NotADirectoryError
#       InterruptedError
#         InterruptedSystemCall
#       PermissionError
#       ProcessLookupError
#       TimeoutError
#       UnsupportedOperation
#       herror
#       gaierror
#       SSLError
#         SSLCertVerificationError
#         SSLZeroReturnError
#         SSLWantWriteError
#         SSLWantReadError
#         SSLSyscallError
#         SSLEOFError
#       Error
#         SameFileError
#       SpecialFileError
# ...

# %%
Q3

# %%
#ZeroDivisionError:
try:
    result = 10 / 0
except ZeroDivisionError as e:
    print("Caught an exception:", e)
#OverflowError
try:
    large_number = 10 ** 1000
except OverflowError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: division by zero

# %%
Q4

# %%
#The LookupError class is a subclass of the Exception class.
#It is used to handle errors that occur when you try to access a key or index that does not exist.
#KeyError: This error is raised when you try to access a key that does not exist in a dictionary.
#For example, the following code will raise a KeyError exception:
dictionary = {"name": "John", "age": 30}
print(dictionary["address"])
#IndexError: This error is raised when you try to access an index that does not exist in a list.
#For example, the following code will raise an IndexError exception:
list = [1, 2, 3]
print(list[3])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 6
#       1 #The LookupError class is a subclass of the Exception class.
#       2 #It is used to handle errors that occur when you try to access a key or index that does not exist.
#       3 #KeyError: This error is raised when you try to access a key that does not exist in a dictionary.
#       4 #For example, the following code will raise a KeyError exception:
#       5 dictionary = {"name": "John", "age": 30}
# ----> 6 print(dictionary["address"])
#       7 #IndexError: This error is raised when you try to access an index that does not exist in a list.
#       8 #For example, the following code will raise an IndexError exception:
#       9 list = [1, 2, 3]
#
# KeyError: 'address'

# %%
Q5

# %% [markdown]
# The ImportError class is a subclass of the Exception class.
# ModuleNotFoundError: This error is raised when Python cannot find the module that is being imported.

# %%
Q6

# %% [markdown]
# Use try and except blocks to handle exceptions. The try block contains the code that you want to execute, and the except block contains the code that you want to execute if an exception is raised.
# Use specific exception types in the except clause. This will help you to narrow down the scope of the exception and to handle the exception more specifically.
# Use the else clause to execute code if no exception is raised. This is a good way to execute code that is common to both the try and except blocks.
# Use the finally clause to execute code that is always executed, regardless of whether or not an exception is raised. This is a good way to close files, free memory, or perform other cleanup tasks.
